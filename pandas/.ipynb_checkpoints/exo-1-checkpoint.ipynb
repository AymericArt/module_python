# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt


house_pricing = pd.read_csv("data/house_pricing.csv", index_col=0, parse_dates=True)
house_pricing.head(10)
types = house_pricing.dtypes
pd.Series(types)
house_pricing.describe(include='all')
pd.Series(house_pricing.isnull().sum()).sort_values(ascending=False)
# Out:
# PoolQC         1453
# MiscFeature    1406
# Alley          1369
# Fence          1179
# FireplaceQu     690
#                ...
# Heating           0
# HeatingQC         0
# MSZoning          0
# 1stFlrSF          0
# SalePrice         0
# Length: 80, dtype: int64

# %%
sb.scatterplot(data=house_pricing, x="SalePrice", y="LotArea")
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %%
lotFilter = house_pricing.where(house_pricing['LotArea'] < 20000)
SalePriceFilter = lotFilter.where(lotFilter['SalePrice'] < 500000)

# %%
sb.scatterplot(data=SalePriceFilter, x="SalePrice", y="LotArea")
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %%
sb.scatterplot(data=SalePriceFilter, x="LotFrontage", y="LotArea")
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='LotArea'>

# %%
#LotFrontageFilter = SalePriceFilter.where(lotFilter['LotFrontage'] < 200)
#LotAreaFilter = LotFrontageFilter.where(lotFilter['LotFrontage'] < 100000)

# %%
sb.scatterplot(data=LotAreaFilter, x="LotFrontage", y="LotArea")
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='LotArea'>
